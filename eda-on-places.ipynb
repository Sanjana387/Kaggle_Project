# %% [markdown]
# <a href="https://www.kaggle.com/code/sanjanchaudhari/eda-on-places?scriptVersionId=137319681" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# ![](https://hips.hearstapps.com/hmg-prod/images/mexiko-yucatan-las-coloradas-pink-lake-salt-lake-royalty-free-image-1570209145.jpg)

# %% [markdown]
# <h1 style="background-color:skyblue; color:white; font-size:40px; font-weight:bold; font-family:Times New Roman;" >Import necessary libraries 🏤📚</h1>

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:98: UserWarning: unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so: undefined symbol: _ZN3tsl6StatusC1EN10tensorflow5error4CodeESt17basic_string_viewIcSt11char_traitsIcEENS_14SourceLocationE']
#   warnings.warn(f"unable to load libtensorflow_io_plugins.so: {e}")
# ...

# %% [markdown]
# <h1 style="background-color:skyblue; color:white; font-size:40px; font-weight:bold; font-family:Times New Roman;" >Import the dataset 💾 </h1>

# %%
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/places-dataset/places.csv

# %% [markdown]
# <h1 style="background-color:skyblue; color:white; font-size:40px; font-weight:bold; font-family:Times New Roman;" >Read the dataset 💾 </h1>

# %%
df=pd.read_csv("/kaggle/input/places-dataset/places.csv")
df.head(2)
# Out:
#          City  Climate  HousingCost  HlthCare  Crime  Transp  Educ  Arts  \
# 0  Abilene,TX      521         6200       237    923    4031  2757   996
# 1    Akron,OH      575         8138      1656    886    4883  2438  5564
#
#    Recreat  Econ  CaseNum    Long     Lat     Pop  StNum
# 0     1405  7633        1 -99.689  32.559  110932     44
# 1     2632  4350        2 -81.518  41.085  660328     36

# %% [markdown]
# <h1 style="background-color:skyblue; color:white; font-size:40px; font-weight:bold; font-family:Times New Roman;" >EDA - Exploratary Data Analysis ⚒️  </h1>

# %% [markdown]
# To perform exploratory data analysis (EDA) on the given dataset, we first need to understand its structure and contents. Based on the code you provided, it seems you have loaded a CSV file named "places.csv" using pandas into a DataFrame named "df." Let's begin by examining the dataset's general information and then proceed with various EDA steps.

# %% [markdown]
# # **1.General Dataset Information:**
# To get an overview of the dataset, we can examine its structure, column names, and data types. Here's an example of how you can retrieve this information:

# %%
df.shape
# Out:
# (329, 15)

# %%
df.dtypes
# Out:
# City            object
# Climate          int64
# HousingCost      int64
# HlthCare         int64
# Crime            int64
# Transp           int64
# Educ             int64
# Arts             int64
# Recreat          int64
# Econ             int64
# CaseNum          int64
# Long           float64
# Lat            float64
# Pop              int64
# StNum            int64
# dtype: object

# %% [markdown]
# # **2.Summary Statistics:**
# Summary statistics provide insights into the central tendency, dispersion, and distribution of the numerical columns in the dataset. You can use the describe() function to generate summary statistics for the numerical columns:

# %%
# Summary statistics
df.describe().transpose()
# Out:
#              count           mean            std         min         25%  \
# Climate      329.0     538.732523     120.808259    105.0000     480.000
# HousingCost  329.0    8346.559271    2385.262622   5159.0000    6760.000
# HlthCare     329.0    1185.738602    1003.002036     43.0000     583.000
# Crime        329.0     961.054711     357.154186    308.0000     707.000
# Transp       329.0    4210.082067    1451.179240   1145.0000    3141.000
# Educ         329.0    2814.887538     320.792953   1701.0000    2619.000
# Arts         329.0    3150.884498    4642.283738     52.0000     778.000
# Recreat      329.0    1845.957447     807.888171    300.0000    1316.000
# Econ         329.0    5525.364742    1084.468523   3045.0000    4842.000
# CaseNum      329.0     165.000000      95.118347      1.0000      83.000
# Long         329.0     -90.178579      14.625073   -127.2016     -96.685
# Lat          329.0      38.181389       5.123326     25.6465      34.223
# ...

# %% [markdown]
# # **3.Missing Values:**
# Missing values can affect the quality and reliability of the data. It is essential to identify and handle missing values appropriately. You can check for missing values in the dataset using the isnull() function and then calculate the total count of missing values in each column using sum():

# %%
df.isnull().sum()
# Out:
# City           0
# Climate        0
# HousingCost    0
# HlthCare       0
# Crime          0
# Transp         0
# Educ           0
# Arts           0
# Recreat        0
# Econ           0
# CaseNum        0
# Long           0
# Lat            0
# Pop            0
# StNum          0
# dtype: int64

# %% [markdown]
# # **4.Unique Values:**
# Understanding the unique values in categorical columns helps us identify the distinct categories and their frequencies. Here's an example of how you can find the unique values and their counts in each column:

# %%
\
for column in df.columns:
    if df[column].dtype == object:  # Check for categorical columns
        print("\nUnique values in", column, "column:")
        print( df[column].value_counts())
# Out:
# Unique values in City column:
# Abilene,TX                                    1
# Oxnard-Ventura,CA                             1
# Orlando,FL                                    1
# Orange-County,NY                              1
# Omaha,NE-IA                                   1
#                                              ..
# Fort-Pierce,FL                                1
# Fort-Myers,FL                                 1
# Fort-Lauderdale-Hollywood-Pompano-Beach,FL    1
# Fort-Collins-Lover=land,CO                    1
# Yuba-City,CA                                  1
# Name: City, Length: 329, dtype: int64

# %%
df.columns
# Out:
# Index(['City', 'Climate', 'HousingCost', 'HlthCare', 'Crime', 'Transp', 'Educ',
#        'Arts', 'Recreat', 'Econ', 'CaseNum', 'Long', 'Lat', 'Pop', 'StNum'],
#       dtype='object')

# %%
# Sort the DataFrame by 'Crime' column in descending order
df_sorted = df.sort_values(by='Crime', ascending=False)

# Extract the top 10 cities with the highest crime rates
top_10_cities = df_sorted.head(10)

# Create a horizontal bar plot
plt.figure(figsize=(10, 6))
plt.bar(top_10_cities['City'], top_10_cities['Crime'])
plt.xlabel('Crime Rate')
plt.ylabel('City')
plt.title('Top 10 Cities with Highest Crime Rates')
plt.xticks(rotation=90)
plt.show()

# %%
# Sort the DataFrame by 'Crime' column in descending order
df_sorted = df.sort_values(by='Educ', ascending=False)

# Extract the top 10 cities with the highest crime rates
top_10_cities = df_sorted.head(10)

# Create a horizontal bar plot
plt.figure(figsize=(10, 6))
plt.bar(top_10_cities['City'], top_10_cities['Educ'])
plt.xlabel('Educ Rate')
plt.ylabel('City')
plt.title('Top 10 Cities with Highest Educ Rates')
plt.xticks(rotation=90)
plt.show()

# %%
# Sort the DataFrame by 'Crime' column in descending order
df_sorted = df.sort_values(by='Transp', ascending=False)

# Extract the city with the highest crime rate (first row)
highest_transp_city = df_sorted.iloc[0]['City']

print("Highest Transpose City:-",highest_transp_city)
# Out:
# Highest Transpose City:- New-York,NY

# %%
plt.boxplot(df['Crime'])
plt.xlabel('Crime')
plt.title('Box Plot of Depth')
plt.show()

# %%
df_sorted = df.sort_values(by='Pop', ascending=False)

# Extract the city with the highest crime rate (first row)
highest_pop_city = df_sorted.iloc[0]['City']

print("Highest Population City:-",highest_pop_city)
# Out:
# Highest Population City:- New-York,NY

# %%
plt.figure(figsize=(8, 6))
df['Crime'].value_counts().plot(kind='line')
plt.xlabel('Category')
plt.ylabel('Count')
plt.title('Distribution of crime Level')
plt.show()

# %%
plt.figure(figsize=(8, 6))
df['Econ'].value_counts().plot(kind='line')
plt.xlabel('Category')
plt.ylabel('Count')
plt.title('Distribution of economy Level')
plt.show()

# %%
df.to_csv("places-dataset.csv")
